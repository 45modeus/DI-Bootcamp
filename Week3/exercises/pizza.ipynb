# %%
toppings = []

base_price = 10
topping_price = 2.50

while True:
    topping = input("Enter a pizza topping(or type quit to finish):")

    if topping.lower() == 'quit':
        break
    else:
        toppings.append(topping)
        print(f"Adding {topping} to your pizza.")


print("\n--- Pizza Summary ---")
print("Your toppings:", ", ".join(toppings))

total_cost = base_price + (len(toppings) * topping_price)
print(f"Total cost: ${total_cost:.2f}")
# Out:
# Adding Pepperoni to your pizza.
# Adding Mozarella to your pizza.
# Adding Chicken to your pizza.
# Adding  to your pizza.
#
# --- Pizza Summary ---
# Your toppings: Pepperoni, Mozarella, Chicken,
# Total cost: $20.00
