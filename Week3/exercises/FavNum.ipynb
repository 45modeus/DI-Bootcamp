# %%
my_fav_numbers = {3, 5, 10, 18}
print("My favorite numbers:", my_fav_numbers)
# Out:
# My favorite numbers: {3, 18, 10, 5}

# %%
my_fav_numbers.add(40)
my_fav_numbers.add(99)
print("After adding two numbers:", my_fav_numbers)
# Out:
# After adding two numbers: {3, 99, 5, 40, 10, 18}

# %%
my_fav_numbers.remove(99)
print("After removing one number:", my_fav_numbers)
# Out:
# After removing one number: {3, 5, 40, 10, 18}

# %%
friend_fav_numbers= {5, 10, 15, 20}
print("Friend's favorite numbers:", friend_fav_numbers)
# Out:
# Friend's favorite numbers: {10, 20, 5, 15}

# %%
our_fav_numbers = my_fav_numbers.union(friend_fav_numbers)
print("Our favorite numbers:", our_fav_numbers)
# Out:
# Our favorite numbers: {3, 5, 40, 10, 15, 18, 20}
