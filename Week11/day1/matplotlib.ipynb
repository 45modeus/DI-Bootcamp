# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = x ** 2

fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
x = np.linspace(0, 10, 100)
y = x ** 2

fig, ax = plt.subplots()
ax.plot([1, 2], [1.5, 3], [2, 1], [2.5, 4], [3, 1], [3.5,3])
